# %%
age=22
txt=f"Aftab ahmed  age is{age}"
print(txt)
# Out:
# Aftab ahmed 22

# %%
price=30
print(f"The price is {price} pkr")
# Out:
# The price is 30 pkr

# %%
txt="the price is {2*8} pkr"
print(txt)
# Out:
# the price is {2*8} pkr
