# %%
age=22
txt=f"Aftab ahmed  age is{age}"
print(txt)
# Out:
# Aftab ahmed 22

# %%
price=30
print(f"The price is {price} pkr")
# Out:
# The price is 30 pkr

# %%
txt=f"the price is {2*8} pkr"
print(txt)
# Out:
# the price is 16 pkr

# %% [markdown]
# **Escap Characters**

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
txt="my name is\"Aftab Ahmed\" full name"
print(txt)
# Out:
# my name is"Aftab Ahmed" full name

# %%
txt="\\This is Aftab Ahmed"
print(txt)
# Out:
# \This is Aftab Ahmed

# %%
txt="Backlash\\"
print(txt)
# Out:
# Backlash\

# %%
txt=f"Aftab Ahmed \n age {22} "
print(txt)
# Out:
# Aftab Ahmed
#  age 22

# %%
txt="\r This is Aftab Ahmed"
print(txt)
# Out:
#  This is Aftab Ahmed
