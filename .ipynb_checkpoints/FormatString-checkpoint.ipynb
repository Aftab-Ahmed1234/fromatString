# %%
age=22
txt=f"Aftab ahmed  age is{age}"
print(txt)
# Out:
# Aftab ahmed 22

# %%
price=30
print(f"The price is {price}")
# Out:
#   Cell In[2], line 2
#     print(f"The price is {price})
#           ^
# SyntaxError: unterminated string literal (detected at line 2)
